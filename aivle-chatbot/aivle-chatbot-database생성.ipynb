# %% [markdown]
# # **과제. 청주시 시설관리공단 민원 챗봇 만들기**
#
# * 청주시의 시설관리공단에 있는 FAQ를 벡터DB로 만들어 RAG를 구성해 봅시다.
# * https://www.cjsisul.or.kr/home/sub.do?menukey=48

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### (1) 구글 드라이브

# %% [markdown]
# #### 1) 구글 드라이브 폴더 생성
# * 새 폴더(langchain)를 생성하고
# * 제공 받은 파일을 업로드

# %% [markdown]
# #### 2) 구글 드라이브 연결

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (2) 라이브러리

# %% [markdown]
# #### 1) 필요한 라이브러리 설치

# %% [markdown]
# * requirements.txt 파일의 [경로 복사]를 한 후,
# * 아래 경로에 붙여 넣기

# %%
# 경로 : /content/drive/MyDrive/langchain/requirements.txt
# 경로가 다른 경우 아래 코드의 경로 부분을 수정하세요.

# !pip install -r /content/drive/MyDrive/langchain/requirements.txt
# Out:
# Collecting openai==0.28 (from -r /content/drive/MyDrive/langchain/requirements.txt (line 1))
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Collecting langchain==0.1.20 (from -r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading langchain-0.1.20-py3-none-any.whl.metadata (13 kB)
# Collecting pymupdf (from -r /content/drive/MyDrive/langchain/requirements.txt (line 3))
#   Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (3.7.6)
# Collecting tiktoken (from -r /content/drive/MyDrive/langchain/requirements.txt (line 5))
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting chromadb==0.5.0 (from -r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading chromadb-0.5.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting wikipedia (from -r /content/drive/MyDrive/langchain/requirements.txt (line 7))
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (4.66.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (3.10.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (2.0.32)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain-community<0.1,>=0.0.38 (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.52 (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading langchain_core-0.1.52-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading langchain_text_splitters-0.0.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading langsmith-0.1.104-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (2.8.2)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.2.1)
# Collecting chroma-hnswlib==0.7.3 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading fastapi-0.112.1-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading posthog-3.5.2-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading onnxruntime-1.19.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_api-1.26.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_instrumentation_fastapi-0.47b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (6.4.3)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (0.12.4)
# Collecting kubernetes>=28.1.0 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting orjson>=3.9.12 (from chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.1 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.24.9 (from pymupdf->-r /content/drive/MyDrive/langchain/requirements.txt (line 3))
#   Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->-r /content/drive/MyDrive/langchain/requirements.txt (line 5)) (2024.5.15)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia->-r /content/drive/MyDrive/langchain/requirements.txt (line 7)) (4.12.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (2.0.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi>=0.95.2->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading starlette-0.38.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (2024.7.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (2.0.7)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.2.0,>=0.1.52->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging>=20.0 (from spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4))
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (1.2.0)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.17->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.13.2)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<=8.0.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading importlib_metadata-8.0.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.63.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.26.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_proto-1.26.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_instrumentation_asgi-0.47b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_instrumentation-0.47b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.47b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading opentelemetry_util_http-0.47b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28->-r /content/drive/MyDrive/langchain/requirements.txt (line 1)) (3.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (0.1.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (0.23.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (13.7.1)
# Collecting h11>=0.8 (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading watchfiles-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading websockets-13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (7.0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia->-r /content/drive/MyDrive/langchain/requirements.txt (line 7)) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (4.9)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (3.7.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (3.20.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->-r /content/drive/MyDrive/langchain/requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (2.16.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.20->-r /content/drive/MyDrive/langchain/requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0->-r /content/drive/MyDrive/langchain/requirements.txt (line 6)) (0.6.0)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 5.5 MB/s eta 0:00:00
# Downloading langchain-0.1.20-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.2 MB/s eta 0:00:00
# Downloading chromadb-0.5.0-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 30.5 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 60.0 MB/s eta 0:00:00
# Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 77.3 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 64.8 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.6 MB/s eta 0:00:00
# Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 18.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading fastapi-0.112.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.9 MB/s eta 0:00:00
# Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 58.3 MB/s eta 0:00:00
# Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 54.2 MB/s eta 0:00:00
# Downloading langchain_core-0.1.52-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 19.6 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.0.2-py3-none-any.whl (23 kB)
# Downloading langsmith-0.1.104-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.1/149.1 kB 10.6 MB/s eta 0:00:00
# Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 4.8 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 81.2 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.26.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 4.3 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.26.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.26.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.26.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.6 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.47b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.47b0-py3-none-any.whl (29 kB)
# Downloading opentelemetry_instrumentation_asgi-0.47b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_semantic_conventions-0.47b0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 9.3 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.47b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.26.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 8.7 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 10.2 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.8 MB/s eta 0:00:00
# Downloading posthog-3.5.2-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 3.0 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.3 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 20.5 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.9 MB/s eta 0:00:00
# Downloading importlib_metadata-8.0.0-py3-none-any.whl (24 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.2 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.38.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 79.1 MB/s eta 0:00:00
# Downloading watchfiles-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.7/427.7 kB 26.3 MB/s eta 0:00:00
# Downloading websockets-13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 10.2 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.5 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.8 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: wikipedia, pypika
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=efb7886072c292391b2e2e720e951987af4570b3587b77343a2d23bd5f65a93d
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=27b8e16bb590a1fa35f1e2e1dc1c82189da61fc8706d6a79b0cfdc2cf7a70a20
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built wikipedia pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, tenacity, python-dotenv, PyMuPDFb, packaging, overrides, orjson, opentelemetry-util-http, opentelemetry-proto, mypy-extensions, jsonpointer, importlib-metadata, humanfriendly, httptools, h11, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, wikipedia, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, pymupdf, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, marshmallow, jsonpatch, httpcore, coloredlogs, opentelemetry-semantic-conventions, opentelemetry-instrumentation, openai, onnxruntime, kubernetes, httpx, fastapi, dataclasses-json, opentelemetry-sdk, opentelemetry-instrumentation-asgi, langsmith, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain-core, langchain-text-splitters, langchain-community, chromadb, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.4.0
#     Uninstalling importlib_metadata-8.4.0:
#       Successfully uninstalled importlib_metadata-8.4.0
# Successfully installed PyMuPDFb-1.24.9 asgiref-3.8.1 backoff-2.2.1 bcrypt-4.2.0 chroma-hnswlib-0.7.3 chromadb-0.5.0 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.14 fastapi-0.112.1 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 humanfriendly-10.0 importlib-metadata-8.0.0 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-30.1.0 langchain-0.1.20 langchain-community-0.0.38 langchain-core-0.1.52 langchain-text-splitters-0.0.2 langsmith-0.1.104 marshmallow-3.22.0 mmh3-4.1.0 monotonic-1.6 mypy-extensions-1.0.0 onnxruntime-1.19.0 openai-0.28.0 opentelemetry-api-1.26.0 opentelemetry-exporter-otlp-proto-common-1.26.0 opentelemetry-exporter-otlp-proto-grpc-1.26.0 opentelemetry-instrumentation-0.47b0 opentelemetry-instrumentation-asgi-0.47b0 opentelemetry-instrumentation-fastapi-0.47b0 opentelemetry-proto-1.26.0 opentelemetry-sdk-1.26.0 opentelemetry-semantic-conventions-0.47b0 opentelemetry-util-http-0.47b0 orjson-3.10.7 overrides-7.7.0 packaging-23.2 posthog-3.5.2 pymupdf-1.24.9 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.38.2 tenacity-8.5.0 tiktoken-0.7.0 typing-inspect-0.9.0 uvicorn-0.30.6 uvloop-0.20.0 watchfiles-0.23.0 websockets-13.0 wikipedia-1.4.0

# %% [markdown]
# #### 2) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import os
import openai

from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, Document
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA, ConversationalRetrievalChain

from langchain.memory import ConversationBufferMemory

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ### (3) OpenAI API Key 확인

# %%
# def load_api_key(filepath):
#     with open(filepath, 'r') as file:
#         return file.readline().strip()

# path = '/content/drive/MyDrive/langchain/'

# # API 키 로드 및 환경변수 설정
# openai.api_key = load_api_key(path + 'api_key.txt')
# os.environ['OPENAI_API_KEY'] = openai.api_key

# %% [markdown]
# * ⚠️ 아래 코드셀은, 실행해서 key가 제대로 보이는지 확인하고 삭제하세요.

# %%
print(os.environ['OPENAI_API_KEY'])
# Out:
# sk-svcacct-h6MQscw9uInllFfsu-J_Oj3rxcNhiswpv_Eh7dIqRBasiiddODZT3BlbkFJXZ1UnL7qMUoQPbGQ-GEpUyIgwGbjRSvE6FEvgC9qgqFl4xZ-jAA

# %%
path = '/content/drive/MyDrive/langchain/'

# %% [markdown]
# ## **2.Vector DB 만들기**
#
# * 시설관리 공단의 QA 데이터를 더 추가합니다.
#     * 현재는 4건만 있음
# * 추가한 csv 파일을 로딩해서 vectorDB를 구성
# * 질문을 시도해 봅시다.
# * 메모리를 구성해서

# %% [markdown]
# * 데이터 로딩

# %%
csv_path = 'aivle.csv'
data = pd.read_csv(csv_path, encoding='utf-8')
data.head()
# Out:
#         구분                                                 QA
# 0    공영주차장  공영주차장의 운영시간은 어떻게 되나요?\n노상 공영주차장: 평일 09:00~18:3...
# 1    공영주차장  주차요금을 내고 싶은데 어떻게 해야 하나요?\n주차요금이 발부된 날로부터 10일 이...
# 2  청주실내빙상장  청주실내빙상장 운영시간\n일일입장 10:00~18:00 (12:00~13:00)점심...
# 3  청주실내빙상장  청주실내빙상장 이용료\n입장료 : 성인 3,500원/청소년 3,000원/어린이 2,...

# %% [markdown]
# * 벡터 데이터베이스
#     * Embedding 모델 : text-embedding-ada-002
#     * DB 경로 : path + /db3

# %%
db_path = '../aivle_db'
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
database = Chroma(persist_directory= db_path, embedding_function = embeddings )

# %% [markdown]
# * 데이터 입력
#     * DF to Vector DB

# %%
# 각 행의 데이터를 Document 객체로 변환
documents = [Document(page_content=text) for text in data.loc[0:1, 'QA'].tolist()]

# %%
# 데이터프레임에서 문서 추가
database.add_documents(documents)
# Out:
# ['8106fa9c-da08-4b64-bb8f-408fbe8afd9b',
#  'd456c51a-3d32-4a13-b1ec-aac7265820bd']

# %% [markdown]
# * 입력된 데이터 조회

# %%
database.get()
# Out:
# {'ids': ['8106fa9c-da08-4b64-bb8f-408fbe8afd9b',
#   'd456c51a-3d32-4a13-b1ec-aac7265820bd'],
#  'embeddings': None,
#  'metadatas': [None, None],
#  'documents': ['공영주차장의 운영시간은 어떻게 되나요?\n노상 공영주차장: 평일 09:00~18:30(9시간 30분), 토, 일요일·공휴일 무료\n용암동 공영주차장: 평일 09:00~18:00(9시간), 토, 일요일·공휴일 무료\n도매시장 부설주차장: 평일·토요일 05:00~18:00(13시간), 일요일·공휴일 무료\n환승주차장: 24시간 연중 무휴(365일 운영)\n공영주차장 운영 시간은 변동 될 수 있음',
#   '주차요금을 내고 싶은데 어떻게 해야 하나요?\n주차요금이 발부된 날로부터 10일 이내에 공단에서 운영하는 공영주차장 근무자에게 납부하는 방법\n은행계좌로 송금하는 방법(농협은행 313-01-133975)\n지로고지서 납부방법 : 전국 금융기관에서 납부가능\n인터넷, 텔레뱅킹 이용 방법 : 입금 시 입금자명 차량번호로 변경'],
#  'uris': None,
#  'data': None}

# %%
# 질문으로 유사도 검색해 보기
query = "주차요금은 어떻게 내?"   # 질문할 문장
k = 3                      # 유사도 상위 k 개 문서 가져오기.

result = database.similarity_search_with_score(query, k = k) #← 데이터베이스에서 유사도가 높은 문서를 가져옴
print(result)
print('-'*50)
for doc in result:
    print(f"유사도 점수 : {round(doc[1], 5)}, 문서 내용: {doc[0].page_content}") # 문서 내용 표시
# Out:
# Number of requested results 3 is greater than number of elements in index 2, updating n_results = 2
# [(Document(page_content='주차요금을 내고 싶은데 어떻게 해야 하나요?\n주차요금이 발부된 날로부터 10일 이내에 공단에서 운영하는 공영주차장 근무자에게 납부하는 방법\n은행계좌로 송금하는 방법(농협은행 313-01-133975)\n지로고지서 납부방법 : 전국 금융기관에서 납부가능\n인터넷, 텔레뱅킹 이용 방법 : 입금 시 입금자명 차량번호로 변경'), 0.19700739773705325), (Document(page_content='공영주차장의 운영시간은 어떻게 되나요?\n노상 공영주차장: 평일 09:00~18:30(9시간 30분), 토, 일요일·공휴일 무료\n용암동 공영주차장: 평일 09:00~18:00(9시간), 토, 일요일·공휴일 무료\n도매시장 부설주차장: 평일·토요일 05:00~18:00(13시간), 일요일·공휴일 무료\n환승주차장: 24시간 연중 무휴(365일 운영)\n공영주차장 운영 시간은 변동 될 수 있음'), 0.30083836185410845)]
# --------------------------------------------------
# 유사도 점수 : 0.19701, 문서 내용: 주차요금을 내고 싶은데 어떻게 해야 하나요?
# 주차요금이 발부된 날로부터 10일 이내에 공단에서 운영하는 공영주차장 근무자에게 납부하는 방법
# 은행계좌로 송금하는 방법(농협은행 313-01-133975)
# 지로고지서 납부방법 : 전국 금융기관에서 납부가능
# 인터넷, 텔레뱅킹 이용 방법 : 입금 시 입금자명 차량번호로 변경
# 유사도 점수 : 0.30084, 문서 내용: 공영주차장의 운영시간은 어떻게 되나요?
# 노상 공영주차장: 평일 09:00~18:30(9시간 30분), 토, 일요일·공휴일 무료
# 용암동 공영주차장: 평일 09:00~18:00(9시간), 토, 일요일·공휴일 무료
# 도매시장 부설주차장: 평일·토요일 05:00~18:00(13시간), 일요일·공휴일 무료
# 환승주차장: 24시간 연중 무휴(365일 운영)
# 공영주차장 운영 시간은 변동 될 수 있음

# %%
result[1][1]
# Out:
# 0.30083836185410845

# %% [markdown]
# ## **3.RAG+LLM모델**

# %% [markdown]
# ### (1) 기본모델 구성

# %% [markdown]
# * 모델 : RetrievalQA
#     * LLM 모델 : gpt-3.5-turbo
#     * retriever : 벡터DB
#         * 유사도 높은 문서 3개 가져오도록 설정

# %% [markdown]
# * database를 retriever로 선언하기

# %%
k = 3
retriever = database.as_retriever(search_kwargs={"k": k})

# %% [markdown]
# * 모델 선언

# %%
chat = ChatOpenAI(model="gpt-3.5-turbo")
qa = RetrievalQA.from_llm(llm=chat,  retriever=retriever,  return_source_documents=True)

# %% [markdown]
# * 모델 확인

# %%
query = "주차요금은 어떻게 내?"
result = qa(query)

print(result["result"])
# Out:
# Number of requested results 3 is greater than number of elements in index 2, updating n_results = 2
# 주차요금을 내는 방법은 다음과 같습니다:
# 1. 공영주차장 근무자에게 직접 납부: 주차요금이 발부된 날로부터 10일 이내에 공영주차장 근무자에게 납부할 수 있습니다.
# 2. 은행계좌로 송금: 농협은행 313-01-133975 계좌로 송금할 수 있습니다.
# 3. 지로고지서 납부: 전국 금융기관에서 납부 가능합니다.
# 4. 인터넷 뱅킹 이용: 입금 시 입금자명을 차량번호로 변경하여 납부할 수 있습니다.
#
# 원하는 방법을 선택하여 주차요금을 납부하시면 됩니다.

# %% [markdown]
# ### (2) 메모리관리 모델 생성

# %% [markdown]
# * 모델 선언

# %%
# 모델 선언

chat = ChatOpenAI(model="gpt-3.5-turbo")

# Retriever 지정
k=3
retriever = database.as_retriever(search_kwargs={"k": k})

# 대화 메모리 생성
memory = ConversationBufferMemory(memory_key="chat_history", input_key="question",
                                  output_key="answer", return_messages=True)

# ConversationalRetrievalQA 체인 생성
qa = ConversationalRetrievalChain.from_llm(llm=chat, retriever=retriever, memory=memory,
                                           return_source_documents=True,  output_key="answer")

# %% [markdown]
# * 모델 확인

# %%
query = "주차는 어떻게 해?"
result = qa(query)


print(result["answer"])
# Out:
# Number of requested results 3 is greater than number of elements in index 2, updating n_results = 2
# 주차요금을 내고 싶으시다면, 주차요금이 발부된 날로부터 10일 이내에 공단에서 운영하는 공영주차장 근무자에게 납부하거나 은행계좌로 송금하실 수 있습니다. 또한, 지로고지서를 통해 전국의 금융기관에서 납부하거나 인터넷 뱅킹, 텔레뱅킹을 통해 입금하실 수도 있습니다. 입금 시에는 입금자명을 차량번호로 기입하시면 됩니다.
#
# 또한, 공영주차장의 운영시간은 공영주차장마다 다를 수 있지만, 대체적으로 주중에는 09:00부터 오후 6시까지 운영되며, 주말 및 공휴일에는 무료로 이용할 수 있습니다. 환승주차장은 연중무휴로 24시간 운영됩니다. 다만, 공영주차장의 운영시간은 변동될 수 있으니 주차장을 이용하기 전에 운영시간을 확인하시는 것이 좋습니다.
